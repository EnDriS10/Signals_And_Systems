# %%
#calcular un promedio

import numpy as np

def Promedio(arr):
    prom=0
    N=0
    for j in arr:
        N +=1
        prom=(prom*(N-1) + j)/N
    return prom

#prueba con un vector de datos aleatorios
ar = np.random.random((10000))





print('\n ENSAYO DE VERIFICACIÓN \n')

print('Promedio en línea: ', Promedio(ar),'.Total de muestras: ',N)

#comparo con el promedio del array calculado con numpy
promedio_verificacion = np.mean(ar)
print('Promedio de verificación:', promedio_verificacion)

if abs(Promedio(ar) - promedio_verificacion) < 1e-6:
  print("Exito en la verificación!!")
else:
  print("Falla en la verificación")
# Out:
#  ENSAYO DE VERIFICACIÓN
#
# Promedio en línea:  0.4991483311678382 .Total de muestras:  10000
# Promedio de verificación: 0.4991483311678354
# Exito en la verificación!!
